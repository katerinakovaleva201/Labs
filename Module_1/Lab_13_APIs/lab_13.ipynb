# %%
# Challenge 1

# %%
import requests
response = requests.get("https://xkcd.com")
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3039', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Tue, 24 Jan 2023 05:08:14 GMT', 'ETag': 'W/"63cf67be-1e2f"', 'Expires': 'Wed, 25 Jan 2023 03:56:40 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 25 Jan 2023 11:46:47 GMT', 'Age': '257', 'X-Served-By': 'cache-dfw-kdfw8210070-DFW, cache-cdg20721-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '9, 1', 'X-Timer': 'S1674647208.622023,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
response.headers["Expires"]
# Out:
# 'Wed, 25 Jan 2023 03:56:40 GMT'

# %%
# HTML codes

response.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Lane Change Highway</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<!-- <script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script> -->\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Lane Change Highway">\n<meta property="og:url" content="https://xkcd.com/2728/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/lane_change_highway_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<di
# ...

# %%
from IPython.display import Image
import requests, json 

catURL = 'https://xkcd.com/info.0.json'
Image(url=requests.get(catURL).json()['img'])

# imageURL = json.loads(requests.get(catURL).content)["file"]
# img = Image(requests.get(imageURL).content)
# display(img)
# Out:
# <img src="https://imgs.xkcd.com/comics/lane_change_highway.png"/>

# %%
# Challenge 2

# %%
import requests, json
# View url:
response1 = requests.get("https://httpbin.org/get")
response1.url
# Out:
# 'https://httpbin.org/get'

# %%
# Add parameters:
params={'things':2, 'total':25}
response2=requests.get("https://httpbin.org/get",params=params)
print(response2.content)
# Out:
# b'{\n  "args": {\n    "things": "2", \n    "total": "25"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.1", \n    "X-Amzn-Trace-Id": "Root=1-63d2592c-7ac3931326b4f20e24375fa2"\n  }, \n  "origin": "185.146.221.98", \n  "url": "https://httpbin.org/get?things=2&total=25"\n}\n'

# %%
# Add username and password as parameters
# Export username and password as dictionary:
params={'username':'Katia', 'password':'123123'}
response3=requests.get("https://httpbin.org/get",params=params)
response3.json()['args']
# Out:
# {'password': '123123', 'username': 'Katia'}

# %%
# Challenge 3

# %%
pip install pygithub
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#      -------------------------------------- 297.6/297.6 kB 2.1 MB/s eta 0:00:00
# ...

# %%
from github import Github
import json
import requests
import pandas as pd
import re
#link to my token
my_git = Github('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')

# %%
# code?q=.scavengerhunt+in:path+repo:inronhack-datalabs/scavenger
# ?q = query
# + another parameter(inside a parameter you can put an "add")
# +in:path+repo: 

response = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
search

# to be completed
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...
